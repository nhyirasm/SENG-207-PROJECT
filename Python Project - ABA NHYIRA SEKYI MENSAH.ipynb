# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### THE DATASET

# %%
# Load dataset
df = pd.read_csv('data.csv')
df
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ### Check for null values

# %%
# Check for null values
print(df.isnull().sum())
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %% [markdown]
# ### Remove null values

# %%
# Remove null values
df.dropna(inplace=True)

# %% [markdown]
# ##### Null values of this dataset were removed because the number of null values as compared to the entire dataset were relatively small hence, removing these null values would not have much of an effect on the dataset. Also, the mean of columns with null values was not used as some columns may have outliers in their dataset and might not give a very accurate analysis of the data

# %% [markdown]
# ### Check for duplicates

# %%
# Check for duplicates
print('Number of duplicates:', df.duplicated().sum())
# Out:
# Number of duplicates: 0

# %% [markdown]
# ### Summary statistics of entire dataset

# %%
# Summary statistics of entire dataset
print(df.describe())
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1591.000000    1591.000000       1591.000000  1591.000000
# mean    801.060968       8.320616          0.527681     0.271477
# std     460.740942       1.740134          0.179045     0.194807
# min       1.000000       4.600000          0.120000     0.000000
# 25%     402.500000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1591.000000  1591.000000          1591.000000           1591.000000
# mean         2.540761     0.087500            15.861722             46.498429
# std          1.413076     0.047175            10.429385             32.998659
# ...

# %% [markdown]
# ### Statistical inferences of individual columns

# %%
# Statistical inferences of individual columns
print(df['alcohol'].describe())
# Out:
# count    1591.000000
# mean       10.426053
# std         1.066706
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
print(df['pH'].describe())
# Out:
# count    1591.000000
# mean        3.311358
# std         0.154548
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
print(df['fixed acidity'].describe())
# Out:
# count    1591.000000
# mean        8.320616
# std         1.740134
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
print(df['volatile acidity'].describe())
# Out:
# count    1591.000000
# mean        0.527681
# std         0.179045
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64

# %%
print(df['citric acid'].describe())
# Out:
# count    1591.000000
# mean        0.271477
# std         0.194807
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64

# %%
print(df['residual sugar'].describe())
# Out:
# count    1591.000000
# mean        2.540761
# std         1.413076
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual sugar, dtype: float64

# %%
print(df['chlorides'].describe())
# Out:
# count    1591.000000
# mean        0.087500
# std         0.047175
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
print(df['free sulfur dioxide'].describe())
# Out:
# count    1591.000000
# mean       15.861722
# std        10.429385
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free sulfur dioxide, dtype: float64

# %%
print(df['total sulfur dioxide'].describe())
# Out:
# count    1591.000000
# mean       46.498429
# std        32.998659
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        62.000000
# max       289.000000
# Name: total sulfur dioxide, dtype: float64

# %%
print(df['density'].describe())
# Out:
# count    1591.000000
# mean        0.996747
# std         0.001889
# min         0.990070
# 25%         0.995600
# 50%         0.996750
# 75%         0.997845
# max         1.003690
# Name: density, dtype: float64

# %%
print(df['quality'].describe())
# Out:
# count    1591.000000
# mean        5.637964
# std         0.807772
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
print(df['sulphates'].describe())
# Out:
# count    1591.000000
# mean        0.658611
# std         0.169786
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
# Histogram of alcohol column
sns.histplot(df['alcohol'], kde=False, bins=20, color='blue')
plt.title('Histogram of Alcohol')
plt.xlabel('Alcohol')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram of pH column
sns.histplot(df['pH'], kde=False, bins=20, color='green')
plt.title('Histogram of pH')
plt.xlabel('pH')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram of Fixed Acidity column
sns.histplot(df['fixed acidity'], kde=False, bins=20, color='purple')
plt.title('Histogram of Fixed Acidity')
plt.xlabel('fixed acidity')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram of quality column
sns.histplot(df['quality'], kde=False, bins=20, color='orange')
plt.title('Histogram of Quality')
plt.xlabel('Quality')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram of pH column
sns.histplot(df['residual sugar'], kde=False, bins=20, color='red')
plt.title('Histogram of residual sugar')
plt.xlabel('residual sugar')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram of pH column
sns.histplot(df['density'], kde=False, bins=20, color='brown')
plt.title('Histogram of density')
plt.xlabel('density')
plt.ylabel('Frequency')
plt.show()

# %%
# Scatter plot of alcohol vs pH
sns.scatterplot(x='alcohol', y='pH', data=df)
plt.title('Scatter Plot of Alcohol vs pH')
plt.xlabel('Alcohol')
plt.ylabel('pH')
plt.show()

# %%
# Correlation heatmap
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
